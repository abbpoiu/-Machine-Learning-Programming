# %%
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/winequality-white.csv", sep=';')  # 핵심: sep=';'
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 0         8.8        6
# 1         9.5        6
# 2        10.1        6
# 3         9.9        6
# 4         9.9        6
# ...       ...      ...
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6
#
# [4898 rows x 12 columns]

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# y가 3~9 점수(정수/문자 혼재 가능)라고 가정

le = LabelEncoder()
df['quality'] = le.fit_transform(df['quality'])
df   # 3~9 → 0~6 같은 연속 라벨로 매핑
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 0         8.8        3
# 1         9.5        3
# 2        10.1        3
# 3         9.9        3
# 4         9.9        3
# ...       ...      ...
# 4893     11.2        3
# 4894      9.6        2
# 4895      9.4        3
# 4896     12.8        4
# 4897     11.8        3
#
# [4898 rows x 12 columns]

# %%
df['quality'].value_counts()
# Out:
# quality
# 3    2198
# 2    1457
# 4     880
# 5     175
# 1     163
# 0      20
# 6       5
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
#칼럼명 확인 후 결측지 확인을 해야됨
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
#레이블 불균형 확인
#어디에 초점이 맞춰져있는 데이터인지 확인.
df['quality'].value_counts()
# Out:
# quality
# 3    2198
# 2    1457
# 4     880
# 5     175
# 1     163
# 0      20
# 6       5
# Name: count, dtype: int64

# %%
# 입력과 출력 분리

X = df.drop(columns=["quality"])
y = df["quality"]

# %%
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol
# 0         8.8
# 1         9.5
# 2        10.1
# 3         9.9
# 4         9.9
# ...       ...
# 4893     11.2
# 4894      9.6
# 4895      9.4
# 4896     12.8
# 4897     11.8
#
# [4898 rows x 11 columns]

# %%
y
# Out:
# 0       3
# 1       3
# 2       3
# 3       3
# 4       3
#        ..
# 4893    3
# 4894    2
# 4895    3
# 4896    4
# 4897    3
# Name: quality, Length: 4898, dtype: int64

# %%
#레이블 갯수확인
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x=y)
plt.xlabel("quality (encoded 0..6)")
plt.ylabel("count")
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
#one hot encoding
Y = pd.get_dummies(y).values

import numpy as np
X = np.asarray(X) #넘파이 형태로 변형. X = X.values가 오류가 생겨서 사용

# %%
X
# Out:
# array([[ 7.  ,  0.27,  0.36, ...,  3.  ,  0.45,  8.8 ],
#        [ 6.3 ,  0.3 ,  0.34, ...,  3.3 ,  0.49,  9.5 ],
#        [ 8.1 ,  0.28,  0.4 , ...,  3.26,  0.44, 10.1 ],
#        ...,
#        [ 6.5 ,  0.24,  0.19, ...,  2.99,  0.46,  9.4 ],
#        [ 5.5 ,  0.29,  0.3 , ...,  3.34,  0.38, 12.8 ],
#        [ 6.  ,  0.21,  0.38, ...,  3.26,  0.32, 11.8 ]])

# %%
# train, test split
from sklearn.model_selection import train_test_split
X_train,X_test, y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
# -------------------------------------------------
# 5) 모델 정의 (작고 탄탄한 MLP)
# -------------------------------------------------
from tensorflow.keras import models, layers

model = models.Sequential([
    layers.Dense(64, activation="relu", input_shape=(X.shape[1],)),
    layers.Dropout(0.3),
    layers.Dense(32, activation="relu"),
    layers.Dense(Y.shape[1], activation="softmax")   # 클래스 수 맞춤
])

model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",   # one-hot이면 categorical_crossentropy
    metrics=["accuracy"]
)

model.summary() #딥러닝 모델의 구조와 파라미터 정보를 표로 보여줌
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 64)             │           768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 7)              │           231 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,079 (12.03 KB)
#  Trainable params: 3,079 (12.03 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# 모델 학습
history = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=50,
    batch_size=16,
    verbose=1,
)
# 테스트 데이터 예측
y_pred = model.predict(X_test)

# 클래스 인덱스로 변환
y_test_class = np.argmax(y_test, axis=1)
y_pred_class = np.argmax(y_pred, axis=1)
# Out:
# Epoch 1/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.3279 - loss: 6.4606 - val_accuracy: 0.4681 - val_loss: 1.7849
# Epoch 2/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.3372 - loss: 2.2101 - val_accuracy: 0.4656 - val_loss: 1.4299
# Epoch 3/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3884 - loss: 1.5761 - val_accuracy: 0.4745 - val_loss: 1.2821
# Epoch 4/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4151 - loss: 1.4096 - val_accuracy: 0.4656 - val_loss: 1.2533
# Epoch 5/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4450 - loss: 1.2964 - val_accuracy: 0.4758 - val_loss: 1.2271
# Epoch 6/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4476 - loss: 1.2924 - val_accuracy: 0.4732 - val_loss: 1.2043
# Epoch 7/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4404 - loss: 1.2969 - val_accuracy: 0.4732 - val_loss: 1.2005
# Epoch 8/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4533 - loss: 1.2471 - val_accuracy: 0.4834 - val_loss: 1.1913
# Epoch 9/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4526 - loss: 1.2778 - val_accuracy: 0.4605 - val_loss: 1.1969
# Epoch 10/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4437 - loss: 1.2255 - val_accuracy: 0.4949 - val_loss: 1.1852
# Epoch 11/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4491 - loss: 1.2441 - val_accuracy: 0.4719 - val_loss: 1.1730
# Epoch 12/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4700 - loss: 1.2304 - val_accuracy: 0.4783 - val_loss: 1.1789
# Epoch 13/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4634 - loss: 1.2104 - val_accuracy: 0.4860 - val_loss: 1.1660
# Epoch 14/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4650 - loss: 1.1963 - val_accuracy: 0.5013 - val_loss: 1.1617
# Epoch 15/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4744 - loss: 1.2423 - val_accuracy: 0.4898 - val_loss: 1.1524
# Epoch 16/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4499 - loss: 1.2191 - val_accuracy: 0.4770 - val_loss: 1.1643
# Epoch 17/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4689 - loss: 1.2279 - val_accuracy: 0.4796 - val_loss: 1.1527
# Epoch 18/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4608 - loss: 1.2280 - val_accuracy: 0.4974 - val_loss: 1.1573
# Epoch 19/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4836 - loss: 1.1965 - val_accuracy: 0.4821 - val_loss: 1.1469
# Epoch 20/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4626 - loss: 1.2130 - val_accuracy: 0.4809 - val_loss: 1.1386
# Epoch 21/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4666 - loss: 1.1901 - val_accuracy: 0.4745 - val_loss: 1.1506
# Epoch 22/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4723 - loss: 1.1845 - val_accuracy: 0.4936 - val_loss: 1.1378
# Epoch 23/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4608 - loss: 1.2065 - val_accuracy: 0.4834 - val_loss: 1.1403
# Epoch 24/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4793 - loss: 1.1744 - val_accuracy: 0.4821 - val_loss: 1.1203
# Epoch 25/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4671 - loss: 1.1951 - val_accuracy: 0.4783 - val_loss: 1.1331
# Epoch 26/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4882 - loss: 1.1780 - val_accuracy: 0.4936 - val_loss: 1.1230
# Epoch 27/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4854 - loss: 1.1706 - val_accuracy: 0.4834 - val_loss: 1.1219
# Epoch 28/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4728 - loss: 1.1438 - val_accuracy: 0.4923 - val_loss: 1.1156
# Epoch 29/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4843 - loss: 1.1606 - val_accuracy: 0.4974 - val_loss: 1.1173
# Epoch 30/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4853 - loss: 1.1737 - val_accuracy: 0.4962 - val_loss: 1.1105
# Epoch 31/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4908 - loss: 1.1400 - val_accuracy: 0.5102 - val_loss: 1.1129
# Epoch 32/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4733 - loss: 1.1564 - val_accuracy: 0.5038 - val_loss: 1.1092
# Epoch 33/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4868 - loss: 1.1590 - val_accuracy: 0.5051 - val_loss: 1.1223
# Epoch 34/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4855 - loss: 1.1424 - val_accuracy: 0.5026 - val_loss: 1.1132
# Epoch 35/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4731 - loss: 1.1599 - val_accuracy: 0.5102 - val_loss: 1.0961
# Epoch 36/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4825 - loss: 1.1766 - val_accuracy: 0.5166 - val_loss: 1.1010
# Epoch 37/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4698 - loss: 1.1413 - val_accuracy: 0.5000 - val_loss: 1.1124
# Epoch 38/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4736 - loss: 1.1499 - val_accuracy: 0.5242 - val_loss: 1.0940
# Epoch 39/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4898 - loss: 1.1246 - val_accuracy: 0.5128 - val_loss: 1.0986
# Epoch 40/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4914 - loss: 1.1345 - val_accuracy: 0.5051 - val_loss: 1.0855
# Epoch 41/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5053 - loss: 1.1341 - val_accuracy: 0.5077 - val_loss: 1.0943
# Epoch 42/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5119 - loss: 1.1279 - val_accuracy: 0.4936 - val_loss: 1.0996
# Epoch 43/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4924 - loss: 1.1424 - val_accuracy: 0.4987 - val_loss: 1.0838
# Epoch 44/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4905 - loss: 1.1189 - val_accuracy: 0.5038 - val_loss: 1.0820
# Epoch 45/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4964 - loss: 1.1251 - val_accuracy: 0.5064 - val_loss: 1.0972
# Epoch 46/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4825 - loss: 1.1221 - val_accuracy: 0.4949 - val_loss: 1.1050
# Epoch 47/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5113 - loss: 1.0989 - val_accuracy: 0.5179 - val_loss: 1.0807
# Epoch 48/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4867 - loss: 1.1526 - val_accuracy: 0.5281 - val_loss: 1.0829
# Epoch 49/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5002 - loss: 1.1160 - val_accuracy: 0.4923 - val_loss: 1.1024
# Epoch 50/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4959 - loss: 1.1317 - val_accuracy: 0.5217 - val_loss: 1.0870
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
# 학습 곡선
loss = history.history['loss']
val_loss = history.history['val_loss']
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

y_pred = model.predict(X_test)

y_test_class = np.argmax(y_test,axis=1)
y_pred_class = np.argmax(y_pred,axis=1)
# Out:
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
#Accuracy of the predicted values
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test_class,y_pred_class))
print(confusion_matrix(y_test_class,y_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.22      0.33         9
#            1       0.00      0.00      0.00        51
#            2       0.49      0.46      0.47       295
#            3       0.45      0.76      0.57       409
#            4       0.62      0.04      0.08       183
#            5       0.00      0.00      0.00        33
#
#     accuracy                           0.47       980
#    macro avg       0.37      0.25      0.24       980
# weighted avg       0.46      0.47      0.40       980
#
# [[  2   0   5   2   0   0]
#  [  1   0  33  17   0   0]
#  [  0   0 135 160   0   0]
#  [  0   1  92 311   5   0]
#  [  0   0  12 162   8   1]
#  [  0   0   1  32   0   0]]
